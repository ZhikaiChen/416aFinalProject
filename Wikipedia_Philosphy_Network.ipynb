# %%
from operator import itemgetter
import networkx as nx
import wikipedia


SEED = "philosophy".title()

STOPS = ("International Standard Serial Number",
        "International Standard Book Number",
        "National Diet Library",
        "International Standard Name Identifier",
        "International Standard Book Number (Identifier)",
        "Pubmed Indentifier",
        "Pubmed Central",
        "Digital Object Identifier",
        "Arxiv",
        "Proc Natl Acad Sci Usa",
         "Bibcode",
        "Librart Of Congress COntrol Number",
        "Jstor")

'''
Credit to Complex Network Analysis in Python by Dmitry Zinoviev
Needs two data structures for the unprocessed pages because you want to know whether a page has been already recorded
(an unordered lookup) and which page is the next to be processed (an orderesd lookup)
'''

todo_lst = [(0, SEED)]
todo_set = set(SEED)
done_set = set()


F= nx.DiGraph()
layer,page = todo_lst[0]

# %%
'''
Doing BFS, one level away from the source "philosophy"
'''
while layer < 2:
    del todo_lst[0]
    done_set.add(page)
    print(layer,page)
    
    try:
        wiki = wikipedia.page(page)
        
    except:
        layer, page = todo_lst[0]
        print("Could not load", page)
        continue
        
    for link in wiki.links:
        link = link.title()
        if link not in STOPS and not link.startswith("list of"):
            if link not in todo_set and link not in done_set:
                todo_lst.append((layer + 1, link))
                todo_set.add(link)
            F.add_edge(page,link)
    layer,page = todo_lst[0]
    
print("{} nodes, {}edges".format(len(F), nx.number_of_edges(F)))
# Out:
# (0, 'Philosophy')
# (1, u'19Th-Century Philosophy')
# (1, u'A.C. Grayling')
# (1, u'A History Of Western Philosophy')
# (1, u'A Priori Knowledge')
# (1, u'Abhidharma')
# (1, u'Absolute (Philosophy)')
# (1, u'Absolute Idealism')
# (1, u'Abstract Object')
# (1, u'Accident (Philosophy)')
# (1, u'Achintya Bheda Abheda')
# (1, u'Action (Philosophy)')
# (1, u'Action Theory (Philosophy)')
# (1, u'Adam Smith')
# (1, u'Adi Shankara')
# (1, u'Advaita Vedanta')
# (1, u'Aesthetic Emotions')
# (1, u'Aesthetics')
# (1, u'African-American Literature')
# (1, u'African-Americans')
# (1, u'African Diaspora')
# (1, u'African People')
# (1, u'African Philosophy')
# (1, u'Africana Philosophy')
# (1, u'Afterlife')
# (1, u'Agriculturalism')
# (1, u'Ahimsa')
# (1, u'Ajivika')
# (1, u'Aj\xf1ana')
# (1, u'Al-Ghazali')
# (1, u'Al-Kindi')
# (1, u'Al-Nahda')
# (1, u'Alan Bullock')
# (1, u'Algonquian Languages')
# (1, u'Allegory Of The Cave')
# (1, u'American Philosophy')
# (1, u'Analects Of Confucius')
# (1, u'Analytic Philosophy')
# (1, u'Analytical Marxism')
# (1, u'Analytical Feminism')
# (1, u'Analytical Philosophy')
# (1, u'Anarchism')
# (1, u'Anatta')
# (1, u'Ancient Egypt')
# (1, u'Ancient Egyptian Philosophy')
# (1, u'Ancient Greece')
# (1, u'Ancient Greek Architecture')
# (1, u'Ancient Greek Philosophy')
# (1, u'Ancient Philosophy')
# (1, u'Anekantavada')
# (1, u'Anicca')
# (1, u'Animal Rights')
# (1, u'Anitya')
# ('Could not load', u'Anselm Of Laon')
# (1, u'Anselm Of Laon')
# (1, u'Anthony Kenny')
# (1, u'Anthony Quinton')
# (1, u'Anthropology')
# (1, u'Anti-Realism')
# (1, u'Antihumanism')
# (1, u'Anton Wilhelm Amo')
# (1, u'Applied Ethics')
# (1, u'Arab World')
# (1, u'Arabia')
# (1, u'Arete Of Cyrene')
# (1, u'Aristotelianism')
# (1, u'Aristotle')
# (1, u'Art')
# (1, u'Artha')
# (1, u'Asceticism')
# (1, u'Asian Philosophy')
# (1, u'Astronomy')
# (1, u'Atman (Hinduism)')
# (1, u'Atomism')
# (1, u'Australian Philosophy')
# (1, u'Averroes')
# (1, u'Averroism')
# (1, u'Avicenna')
# (1, u'Avicennism')
# (1, u'Axiology')
# (1, u'Ayn Rand')
# (1, u'Aztec Calendar Stone')
# (1, u'Aztec Codices')
# (1, u'Aztec Philosophy')
# (1, u'B.F. Skinner')
# (1, u'Babylonian Astronomy')
# (1, u'Bantu Philosophy')
# (1, u'Basic Beliefs')
# (1, u'Beauty')
# (1, u'Behaviorism')
# (1, u'Beijing')
# (1, u'Being')
# (1, u'Berggruen Prize For Philosophy')
# (1, u'Bertrand Russell')
# (1, u'Bhagavad Gita')
# (1, u'Bhedabheda')
# (1, u'Biblioteca Nacional De Espa\xf1a')
# (1, u'Biblioth\xe8que Nationale De France')
# (1, u'Black Existentialism')
# (1, u'Boethius')
# (1, u'Brahman')
# (1, u'Brain In A Vat')
# (1, u'British Idealism')
# (1, u'British Philosophy')
# (1, u'Bruce Kuklick')
# (1, u'Buddhism')
# (1, u'Buddhist Ethics')
# (1, u'Buddhist Logic')
# (1, u'Buddhist Philosophy')
# (1, u'Buddhist Texts')
# (1, u'Burma')
# (1, u'Canadian Philosophical Association')
# (1, u'Carl Von Clausewitz')
# (1, u'Carly Fiorina')
# (1, u'Cartesianism')
# (1, u'Causality')
# (1, u'Central Asia')
# (1, u'Chanakya')
# (1, u'Charles Taylor (Philosopher)')
# (1, u'Charvaka')
# (1, u'China')
# (1, u'Chinese Buddhism')
# (1, u'Chinese Marxist Philosophy')
# (1, u'Chinese Philosophy')
# (1, u'Christian Philosophy')
# (1, u'Christianity')
# (1, u'Cicero')
# (1, u'Classical Realism')
# (1, u'Classical Liberalism')
# (1, u'Cognitive Science')
# (1, u'Coherentism')
# (1, u'Colin Mcginn')
# (1, u'Collectivism')
# (1, u'Communism')
# (1, u'Communitarianism')
# (1, u'Compatibilism')
# (1, u'Computational Logic')
# (1, u'Computer Engineering')
# (1, u'Computer Science')
# (1, u'Conceptualism')
# (1, u'Confucianism')
# (1, u'Confucius')
# (1, u'Consequentialism')
# (1, u'Conservatism')
# (1, u'Constructivist Epistemology')
# (1, u'Contemporary Islamic Philosophy')
# (1, u'Contemporary Philosophy')
# (1, u'Continental Philosophy')
# (1, u'Cosmology')
# (1, u'Cosmology (Philosophy)')
# (1, u'Critical Race Theory')
# (1, u'Critical Rationalism')
# (1, u'Critical Theory')
# (1, u'Cubist')
# (1, u'Curlie')
# (1, u'Curtis White (Author)')
# (1, u'Cynicism (Philosophy)')
# (1, u'Cyrenaics')
# (1, u'Czech Philosophy')
# (1, u'C\u0101rv\u0101ka')
# (1, u'Danish Philosophy')
# (1, u'Daoism')
# ('Could not load', u'David Chalmers')
# (1, u'David Chalmers')
# (1, u'David Hume')
# (1, u'Decision Theory')
# (1, u'Deconstruction')
# (1, u'Deductive Reasoning')
# (1, u'Deep Ecology')
# (1, u'Deontological Ethics')
# (1, u'Deontology')
# (1, u'Determinism')
# (1, u'Dharma')
# (1, u'Dialectic')
# (1, u'Digital Humanities')
# (1, u'Dignaga')
# (1, u'Dign\u0101ga')
# (1, u'Diogenes La\xebrtius')
# (1, u'Directory Of American Philosophers')
# ('Could not load', u'Doctorate Of Philosophy')
# (1, u'Doctorate Of Philosophy')
# (1, u'Dogen')
# (1, u'Dualism (Philosophy Of Mind)')
# (1, u'Dualistic Cosmology')
# (1, u'Dukkha')
# (1, u'Dvaita Vedanta')
# (1, u'Dvaitadvaita')
# (1, u'Early Islamic Philosophy')
# (1, u'Early Modern Philosophy')
# (1, u'East Asia')
# (1, u'East Asian Buddhist')
# (1, u'East Asian Cultural Sphere')
# (1, u'Eastern Philosophy')
# (1, u'Economics')
# (1, u'Edo Neo-Confucianism')
# (1, u'Edward Craig (Philosopher)')
# (1, u'Eleatics')
# (1, u'Eliminative Materialism')
# (1, u'Elliott Sober')
# (1, u'Emergentism')
# (1, u'Empiricism')
# (1, u'Environmental Philosophy')
# (1, u'Ephesian School')
# (1, u'Epicureanism')
# (1, u'Epiphenomenalism')
# (1, u'Epistemological Idealism')
# (1, u'Epistemological Particularism')
# (1, u'Epistemology')
# (1, u'Eretrian School')
# (1, u'Essence')
# (1, u'Ethics')
# (1, u'Ethiopian Philosophy')
# (1, u'Ethnophilosophy')
# (1, u'Eudaimonia')
# (1, u'Eugenio Garin')
# (1, u'Event (Philosophy)')
# (1, u'Evil Demon')
# (1, u'Existence')
# (1, u'Existence Of God')
# (1, u'Existentialism')
# (1, u'Experimental Philosophy')
# (1, u'Facebook')
# (1, u'Faith')
# (1, u'Falsifiability')
# (1, u'Feeling')
# (1, u'Feminism')
# (1, u'Feminist Philosophy')
# (1, u'Fertile Crescent')
# (1, u'Fideism')
# (1, u'Film Theory')
# (1, u'Formal Science')
# (1, u'Formalism (Art)')
# (1, u'Foundationalism')
# (1, u'Four Noble Truths')
# (1, u'Frankfurt School')
# (1, u'Frederick Copleston')
# (1, u'Free Will')
# (1, u'French Philosophy')
# (1, u'Friedrich Nietzsche')
# (1, u'Functionalism (Philosophy Of Mind)')
# (1, u'G.E.M. Anscombe')
# (1, u'Gautama Buddha')
# (1, u'Gender Bias')
# (1, u'Generative Grammar')
# (1, u'Geonim')
# (1, u'Georg Wilhelm Friedrich Hegel')
# (1, u'George Berkeley')
# (1, u'Gerd B. Achenbach')
# (1, u'German Idealism')
# (1, u'German Philosophy')
# (1, u'Gitche Manitou')
# (1, u'Glossary Of Philosophy')
# (1, u'Gnosticism')
# (1, u'God')
# (1, u'Good And Evil')
# (1, u'Gottfried Wilhelm Leibniz')
# (1, u'Government')
# (1, u'Greek Language')
# (1, u'Guozijian (Beijing)')
# (1, u'Han Dynasty')
# (1, u'Hannah Arendt')
# (1, u'Hard Determinism')
# (1, u'Hard Incompatibilism')
# (1, u'Harry Frankfurt')
# (1, u'Haskalah')
# (1, u'Hegel')
# (1, u'Hegelianism')
# (1, u'Hellenistic Philosophy')
# (1, u'Henry Corbin')
# (1, u'Hermeneutics')
# (1, u'Hindu Philosophy')
# (1, u'Hinduism')
# (1, u'Hipparchia Of Maroneia')
# (1, u'Historicism')
# (1, u'History')
# (1, u'History Of China')
# (1, u'History Of Iran')
# (1, u'History Of Western Philosophy')
# (1, u'History Of Ethics')
# (1, u'History Of Philosophy In Poland')
# (1, u'Holism')
# (1, u'Hu Shih')
# (1, u'Human Body')
# (1, u'Human Nature')
# (1, u'Humanism')
# (1, u'Humanities')
# (1, u'Hundred Schools Of Thought')
# (1, u'Ipod')
# (1, u'Ibn Khaldun')
# (1, u'Ibn Rushd')
# (1, u'Ibn Taymiyyah')
# (1, u'Idealism')
# (1, u'Illuminationism')
# (1, u'Illuminationist Philosophy')
# (1, u'Immanuel Kant')
# (1, u'Inca Civilization')
# (1, u'Inca Education')
# (1, u'Incompatibilism')
# (1, u'Index Of Philosophy')
# (1, u'Index Of Sociopolitical Thinkers')
# (1, u'Indian Philosophy')
# (1, u'Indian Subcontinent')
# (1, u'Indigenous American Philosophy')
# (1, u'Indigenous People Of The Americas')
# (1, u'Individualism')
# (1, u'Indonesian Philosophy')
# (1, u'Infinitism')
# (1, u'Inside Higher Education')
# (1, u'Integrated Authority File')
# (1, u'Internalism And Externalism')
# (1, u'International Directory Of Philosophy And Philosophers')
# (1, u'International Politics')
# (1, u'Ionian School (Philosophy)')
# (1, u'Iran')
# (1, u'Iranian Philosophy')
# (1, u'Isaac Newton')
# (1, u'Islamic Golden Age')
# (1, u'Islamic Culture')
# (1, u'Islamic Philosophy')
# (1, u'Islamic Theology')
# (1, u'Italian Philosophy')
# (1, u'Jain Philosophy')
# (1, u'Jainism')
# (1, u'Japan')
# (1, u'Japanese Philosophy')
# (1, u'Jean-Jacques Rousseau')
# (1, u'Jean Baudrillard')
# (1, u'Jennifer Saul')
# (1, u'Jewish Existentialism')
# (1, u'Jewish Philosophy')
# (1, u'Johannes Bronkhorst')
# (1, u'John Dewey')
# (1, u'John Locke')
# (1, u'John Rawls')
# (1, u'John Stuart Mill')
# (1, u'Joseon Dynasty')
# (1, u'Judaism')
# (1, u'Judeo-Christian')
# (1, u'Judeo-Islamic Philosophies (800\u20131400)')
# (1, u'Judgment')
# (1, u'Jurisprudence')
# (1, u'Justice')
# (1, u'Kalam')
# (1, u'Kama')
# (1, u'Kant')
# (1, u'Kantianism')
# (1, u'Karl Marx')
# (1, u'Karma')
# (1, u'Kathleen Higgins')
# (1, u'Kierkegaard')
# (1, u'Knowledge')
# (1, u'Kokugaku')
# (1, u'Korean Confucianism')
# (1, u'Korean Philosophy')
# (1, u'Kwame Anthony Appiah')
# (1, u'Kyoto School')
# (1, u'Language')
# (1, u'Larry Sanger')
# (1, u'Latin Language')
# (1, u'Law')
# (1, u'Lectures On The Philosophy Of History')
# (1, u'Legal Positivism')
# (1, u'Legalism (Chinese Philosophy)')
# (1, u'Leo Tolstoy')
# (1, u'Li (Confucianism)')
# (1, u'Libertarianism (Metaphysics)')
# (1, u'Library Of Congress Control Number')
# (1, u'Linguistic Turn')
# (1, u'Linguistics')
# (1, u'List Of Russian Philosophers')
# (1, u'List Of Slovene Philosophers')
# (1, u'List Of Aestheticians')
# (1, u'List Of Epistemologists')
# (1, u'List Of Ethicists')
# (1, u'List Of Important Publications In Philosophy')
# (1, u'List Of Logicians')
# (1, u'List Of Metaphysicians')
# (1, u'List Of Philosophies')
# (1, u'List Of Philosophy Journals')
# (1, u'List Of Unsolved Problems In Philosophy')
# (1, u'List Of Years In Philosophy')
# (1, u'Lists Of Philosophers')
# (1, u'Literary Theory')
# (1, u'Literature')
# (1, u'Lives And Opinions Of Eminent Philosophers')
# (1, u'Logic')
# (1, u'Logical Positivism')
# (1, u'Logical Consequence')
# (1, u'Logos')
# (1, u'Louis C.K.')
# (1, u'Luciano Floridi')
# (1, u'Ludwig Wittgenstein')
# (1, u'Madhyamaka')
# (1, u'Mahatma Gandhi')
# (1, u'Mahavira')
# (1, u'Mahayana')
# (1, u'Maimonides')
# (1, u'Manichaeism')
# (1, u'Mao Zedong')
# (1, u'Martin Luther King Jr')
# (1, u'Martin Luther King Jr.')
# (1, u'Marxism')
# (1, u'Marxist Philosophy')
# (1, u'Materialism')
# (1, u'Mathematical Logic')
# (1, u'Mathematics')
# (1, u'Mazdak')
# (1, u'Mazdakism')
# (1, u'Medicine')
# (1, u'Medieval Philosophy')
# (1, u'Medieval Universities')
# (1, u'Meditation')
# (1, u'Megarian School')
# (1, u'Meirokusha')
# (1, u'Merriam-Webster')
# (1, u'Merriam-Webster Dictionary')
# (1, u'Mesoamerica')
# (1, u'Messianism')
# (1, u'Meta-Analysis')
# (1, u'Meta-Ethics')
# (1, u'Metaphilosophy')
# (1, u'Metaphysical Naturalism')
# (1, u'Metaphysics')
# (1, u'Mexico City')
# (1, u'Michael Sandel')
# (1, u'Michel Weber')
# (1, u'Middle Eastern Philosophy')
# (1, u'Milesian School')
# (1, u'Military Strategy')
# (1, u'Mind')
# (1, u'Mind\u2013Body Dualism')
# (1, u'Ming Dynasty')
# (1, u'Misogyny')
# (1, u'Mixed-Sex Education')
# (1, u'Modal Logic')
# (1, u'Modern Philosophy')
# (1, u'Modernism')
# (1, u'Modus Ponens')
# (1, u'Mohism')
# (1, u'Moksha')
# (1, u'Monism')
# (1, u'Monotheism')
# (1, u'Moral Absolutism')
# (1, u'Moral Nihilism')
# (1, u'Moral Particularism')
# (1, u'Moral Realism')
# (1, u'Moral Skepticism')
# (1, u'Moral Universalism')
# (1, u'Morality')
# (1, u'Moscow')
# (1, u'Moses Mendelssohn')
# (1, u'Motilal Banarsidass')
# (1, u'Music')
# (1, u'Music Theory')
# (1, u'Muslim Conquests')
# (1, u'M\u012bm\u0101\u1e43s\u0101')
# (1, u'Nagarjuna')
# (1, u'National Archives And Records Administration')
# (1, u'National Library Of The Czech Republic')
# (1, u'National Museum Of Anthropology')
# (1, u'Native Americans In The United States')
# (1, u'Natural Law')
# (1, u'Natural Philosophy')
# (1, u'Natural Sciences')
# (1, u'Naturalism (Philosophy)')
# (1, u'Naturalized Epistemology')
# (1, u'Nature')
# (1, u'Navya-Ny\u0101ya')
# (1, u'Neo-Confucianism')
# (1, u'Neo-Kantianism')
# (1, u'Neo-Marxism')
# (1, u'Neo-Scholasticism')
# (1, u'Neoplatonism')
# (1, u'Neopythagoreanism')
# (1, u'New Confucianism')
# (1, u'New Historicism')
# (1, u'Niccol\xf2 Machiavelli')
# (1, u'Nietzsche')
# (1, u'Nigel Warburton')
# (1, u'Nihilism')
# (1, u'Nominalism')
# (1, u'Non-Classical Logic')
# (1, u'Norm (Philosophy)')
# (1, u'Normative Ethics')
# (1, u'Noumenon')
# (1, u'Number')
# (1, u'Nyaya')
# (1, u'N\xe9gritude')
# (1, u'Oclc')
# (1, u'Object (Philosophy)')
# (1, u'Objective Idealism')
# (1, u'Objectivism (Ayn Rand)')
# (1, u'Objectivity (Philosophy)')
# (1, u'Oliver Leaman')
# (1, u'Ometeotl')
# (1, u'On Bullshit')
# (1, u'Ontology')
# (1, u'Open Court Publishing Company')
# (1, u'Ordinary Language Philosophy')
# (1, u'Orenda')
# (1, u'Ornithology')
# (1, u'Outline Of Academic Disciplines')
# (1, u'Outline Of Philosophy')
# (1, u'Padmanabh Jaini')
# (1, u'Pain (Philosophy)')
# (1, u'Pakistani Philosophy')
# (1, u'Pan-Africanism')
# (1, u'Pantheism')
# (1, u'Particular')
# (1, u'Paul Dundas')
# (1, u'Paul Edwards (Philosopher)')
# (1, u'Performing Arts')
# (1, u'Peripatetic School')
# (1, u'Personal Identity')
# (1, u'Peter Thiel')
# (1, u'Phenomenology (Philosophy)')
# (1, u'Phenomenon')
# (1, u'Philalethes')
# (1, u'Philip Sherrard')
# (1, u'Philomath')
# (1, u'Philosopher')
# (1, u'Philosophical Anthropology')
# (1, u'Philosophical Logic')
# (1, u'Philosophical Method')
# (1, u'Philosophical Movement')
# (1, u'Philosophical Progress')
# (1, u'Philosophical Realism')
# (1, u'Philosophical Skepticism')
# (1, u'Philosophi\xe6 Naturalis Principia Mathematica')
# (1, u'Philosophy (Disambiguation)')
# ('Could not load', u'Philosophy And Economics')
# (1, u'Philosophy And Economics')
# (1, u'Philosophy And Literature')
# (1, u'Philosophy Education')
# (1, u'Philosophy For Children')
# (1, u'Philosophy Of Artificial Intelligence')
# (1, u'Philosophy Of Biology')
# (1, u'Philosophy Of Business')
# (1, u'Philosophy Of Chemistry')
# (1, u'Philosophy Of Color')
# (1, u'Philosophy Of Computer Science')
# (1, u'Philosophy Of Culture')
# (1, u'Philosophy Of Design')
# (1, u'Philosophy Of Dialogue')
# (1, u'Philosophy Of Education')
# (1, u'Philosophy Of Engineering')
# (1, u'Philosophy Of Film')
# (1, u'Philosophy Of Futility')
# (1, u'Philosophy Of Geography')
# (1, u'Philosophy Of Happiness')
# (1, u'Philosophy Of Healthcare')
# (1, u'Philosophy Of History')
# (1, u'Philosophy Of Information')
# (1, u'Philosophy Of Language')
# (1, u'Philosophy Of Law')
# (1, u'Philosophy Of Life')
# (1, u'Philosophy Of Mathematics')
# (1, u'Philosophy Of Mind')
# (1, u'Philosophy Of Music')
# (1, u'Philosophy Of Perception')
# (1, u'Philosophy Of Physics')
# (1, u'Philosophy Of Psychiatry')
# (1, u'Philosophy Of Psychology')
# (1, u'Philosophy Of Religion')
# (1, u'Philosophy Of Science')
# (1, u'Philosophy Of Sex')
# (1, u'Philosophy Of Social Science')
# (1, u'Philosophy Of Space And Time')
# (1, u'Philosophy Of Sport')
# (1, u'Philosophy Of Technology')
# (1, u'Philosophy Of War')
# (1, u'Physicalism')
# (1, u'Physics')
# (1, u'Pierre Hadot')
# (1, u'Plastic Arts')
# (1, u'Plato')
# (1, u'Platonic Academy')
# (1, u'Platonism')
# (1, u'Pluralist School')
# (1, u'Political Philosophy')
# (1, u'Politics')
# (1, u'Pope John Paul Ii')
# (1, u'Popular Culture')
# (1, u'Positivism')
# (1, u'Post-Structuralism')
# (1, u'Postanalytic Philosophy')
# (1, u'Postcolonialism')
# (1, u'Posthumanism')
# (1, u'Postmodern Philosophy')
# (1, u'Pragmatism')
# (1, u'Pramana')
# (1, u'Pram\u0101\u1e47a')
# (1, u'Pre-Socratic Philosophy')
# (1, u'Premise')
# (1, u'Problem Of Evil')
# (1, u'Problem Of Religious Language')
# (1, u'Problem Solving')
# (1, u'Process Philosophy')
# (1, u'Professor')
# (1, u'Progress Publishers')
# (1, u'Property (Philosophy)')
# (1, u'Psychology')
# (1, u'Public Administration')
# (1, u'Pyrrhonism')
# (1, u'Pythagoras')
# (1, u'Pythagoreanism')
# (1, u'Qing Dynasty')
# (1, u'Quietism (Philosophy)')
# (1, u'Rangaku')
# (1, u'Raphael')
# (1, u'Rationalism')
# (1, u'Reality')
# (1, u'Reason')
# (1, u'Reasonism')
# (1, u'Reductionism')
# (1, u'Reform Judaism')
# (1, u'Reformed Epistemology')
# (1, u'Regis University')
# (1, u'Regress Argument')
# (1, u'Relationship Between Religion And Science')
# (1, u'Relativism')
# (1, u'Religion')
# (1, u'Religious Epistemology')
# (1, u'Religious Experiences')
# (1, u'Religious Pluralism')
# (1, u'Religious Studies')
# (1, u'Ren (Confucianism)')
# (1, u'Renaissance')
# (1, u'Renaissance Humanism')
# (1, u'Renaissance Philosophy')
# (1, u'Ren\xe9 Descartes')
# (1, u'Richard Feynman')
# (1, u'Richard M. Weaver')
# (1, u'Richard Tarnas')
# (1, u'Ricky Gervais')
# (1, u'Rishabha')
# (1, u'Robert C. Solomon')
# (1, u'Roger Bacon')
# (1, u'Roman Empire')
# (1, u'Romanian Philosophy')
# (1, u'Romans')
# (1, u'Rules Of Inference')
# (1, u'Russian Cosmism')
# (1, u'Sage (Philosophy)')
# (1, u'Samkhya')
# (1, u'Samsara')
# (1, u'Sanskrit Language')
# (1, u'Sarvepalli Radhakrishnan')
# (1, u'Sautr\u0101ntika')
# (1, u'Scholasticism')
# (1, u'School Of Names')
# (1, u'School Of Naturalists')
# (1, u'Science')
# (1, u'Scientific Method')
# (1, u'Scientific Realism')
# (1, u'Scientism')
# (1, u'Scott Soames')
# (1, u'Sebayt')
# (1, u'Seinfeld')
# (1, u'Seneca The Younger')
# (1, u'Senses')
# (1, u'Sera Monastery')
# (1, u'Sexual Harassment')
# (1, u'Shamanism')
# (1, u'Shinto')
# (1, u'Shuddhadvaita')
# (1, u'Shunyata')
# (1, u'Silk Road Transmission Of Buddhism')
# (1, u'Simone De Beauvoir')
# (1, u'Simulacra And Simulation')
# (1, u'Siouan')
# (1, u'Skeptical Movement')
# (1, u'Skepticism')
# (1, u'Social Constructionism')
# (1, u'Social Contract')
# (1, u'Social Philosophy')
# (1, u'Social Science')
# (1, u'Social Theory')
# (1, u'Socialism')
# (1, u'Sociology')
# (1, u'Socrates')
# (1, u'Socratic Method')
# (1, u'Socratic Questioning')
# (1, u'Solipsism')
# (1, u'Sophia (Wisdom)')
# (1, u'Sophist')
# (1, u'Soteriology')
# (1, u'Souls')
# (1, u'South Korea')
# (1, u'Southeast Asia')
# (1, u'Spanish Philosophy')
# (1, u'Spinoza')
# (1, u'Spinozism')
# (1, u'Sri Lanka')
# (1, u'St. Augustine')
# (1, u'Stagira')
# (1, u'Stanford Encyclopedia Of Philosophy')
# (1, u'Star Wars')
# (1, u'State (Polity)')
# (1, u'State Shinto')
# (1, u'Statism In Sh\u014dwa Japan')
# (1, u'Stephen Breyer')
# (1, u'Steve Martin')
# (1, u'Steven Nadler')
# (1, u'Stoicism')
# (1, u'Structuralism')
# (1, u'Subjective Idealism')
# (1, u'Subjectivism')
# (1, u'Sufi Philosophy')
# (1, u'Sun Tzu')
# (1, u'Susanne Langer')
# (1, u'Svatantrika\u2013Prasa\u1e45gika Distinction')
# (1, u'Systemics')
# (1, u'Talmudic Academies In Babylonia')
# (1, u'Tanakh')
# (1, u'Tao')
# (1, u'Taoism')
# (1, u'Taste (Sociology)')
# (1, u'Tattvartha Sutra')
# (1, u'Teodor Oizerman')
# (1, u'Terrence Malick')
# (1, u'Thailand')
# (1, u'Thales')
# (1, u'The Enlightenment')
# (1, u'The Matrix')
# (1, u'The Matrix (Franchise)')
# (1, u'The School Of Athens')
# (1, u'The Simpsons')
# (1, u'Theology')
# (1, u'Theories Of Humor')
# (1, u'Theory Of Art')
# (1, u'Theory Of Justification')
# (1, u'Theravada Buddhist')
# (1, u'Thomas Aquinas')
# (1, u'Thomas Hobbes')
# (1, u'Thomism')
# (1, u'Tibet')
# (1, u'Tibetan Buddhist')
# (1, u'Time')
# (1, u'Tirthankara')
# (1, u'Tlamatini')
# (1, u'Transcendent Theosophy')
# (1, u'Transcendental Idealism')
# (1, u'Transcendentalism')
# (1, u'Truth')
# (1, u'Turkish Philosophy')
# (1, u'U.S. Department Of Education')
# (1, u'Ubuntu (Philosophy)')
# (1, u'Ujamaa')
# (1, u'Universal (Metaphysics)')
# (1, u'Universals')
# ('Could not load', u'University')
# (1, u'University')
# (1, u'University Of Sheffield')
# (1, u'Upanishads')
# (1, u'Utilitarianism')
# (1, u'Utopia')
# (1, u'Vaisheshika')
# (1, u'Value (Ethics)')
# (1, u'Value Theory')
# (1, u'Values (Philosophy)')
# (1, u'Vasubandhu')
# (1, u'Vatican Museum')
# (1, u'Vedanta')
# (1, u'Vedas')
# (1, u'Vedic Period')
# (1, u'Vienna Circle')
# (1, u'Vietnamese Philosophy')
# (1, u'Virtue Ethics')
# (1, u'Vishishtadvaita')
# (1, u'Visual Arts')
# (1, u'Wakan Tanka')
# (1, u'Wang Yangming')
# (1, u'Western Marxism')
# (1, u'Western Roman Empire')
# (1, u'Western Zhou')
# (1, u'Western Canon')
# (1, u'Western Philosophy')
# (1, u'Western World')
# (1, u'Will Durant')
# (1, u'William James')
# (1, u'William L. Reese')
# (1, u'Wing-Tsit Chan')
# (1, u'Wisdom Literature')
# (1, u'Women In Philosophy')
# (1, u'World')
# (1, u'World War Ii')
# (1, u'Wrong')
# (1, u'Xiong Shili')
# (1, u'Xuanxue')
# (1, u'Yanantin')
# (1, u'Yangism')
# (1, u'Yin And Yang')
# (1, u'Yoga (Philosophy)')
# (1, u'Yoga Sutras Of Patanjali')
# (1, u'Yogachara')
# (1, u'Yuan Dynasty')
# (1, u'Zen')
# (1, u'Zera Yacob (Philosopher)')
# (1, u'Zhuangzi (Book)')
# (1, u'Zhuangzi Dreamed He Was A Butterfly')
# (1, u'Zoroaster')
# (1, u'Zoroastrianism')
# (1, u'Zurvanism')
# (1, u'\u0100j\u012bvika')
# (1, u'\u0100stika And N\u0101stika')
# (1, u'\u0100tman (Buddhism)')
# (1, u'\u015a\u016bnyat\u0101')
# 110128 nodes, 425522edges

# %%
'''
concentrate on indegree: the number of edges directed into the node
shrink the size of the graph to raise the average number of edges per node
'''
core = [node for node, deg in dict(F.degree()).items() if deg >= 6]
G = nx.subgraph(F, core)
print("{} nodes, {} edges".format(len(G),nx.number_of_edges(G)))
# Out:
# 10983 nodes, 274848 edges

# %%
top_indegree = sorted(dict(G.in_degree()).items(), reverse=True, key=itemgetter(1))[:100]

for top in top_indegree:
    print(top)
# Out:
# (u'Epistemology', 372)
# ('Philosophy', 360)
# (u'Metaphysics', 353)
# (u'Integrated Authority File', 336)
# (u'Plato', 332)
# (u'Aristotle', 321)
# (u'Immanuel Kant', 316)
# (u'Confucianism', 316)
# (u'Logic', 308)
# (u'Ethic', 308)
# (u'Existentialism', 303)
# (u'Political Philosophy', 302)
# (u'Empiricism', 298)
# (u'Monism', 298)
# (u'Buddhist Philosophy', 297)
# (u'Ludwig Wittgenstein', 297)
# (u'Naturalism (Philosophy)', 296)
# (u'Philosophy Of Social Science', 296)
# (u'Ontology', 295)
# (u'Free Will', 293)
# (u'Determinism', 293)
# (u'Philosophy Of Mind', 292)
# (u'Rationalism', 291)
# (u'Western Philosophy', 290)
# (u'Philosophy Of Science', 288)
# (u'Stoicism', 285)
# (u'Utilitarianism', 285)
# (u'Materialism', 285)
# (u'Atomism', 284)
# (u'John Rawls', 282)
# (u'Analytic Philosophy', 282)
# (u'Social Philosophy', 282)
# (u'Logical Positivism', 281)
# (u'Reductionism', 280)
# (u'Anti-Realism', 278)
# (u'Physicalism', 278)
# (u'Philosophy Of Psychology', 278)
# (u'Socialism', 277)
# (u'Objectivity (Philosophy)', 277)
# (u'Legalism (Chinese Philosophy)', 277)
# (u'\u015a\u016bnyat\u0101', 277)
# (u'Vedanta', 276)
# (u'Madhyamaka', 276)
# (u'Idealism', 275)
# (u'Indian Philosophy', 275)
# (u'Ancient Greek Philosophy', 275)
# (u'Pragmatism', 275)
# (u'Justice', 275)
# (u'Philosophy Of History', 274)
# (u'Aesthetic', 271)
# (u'Scholasticism', 271)
# (u'Nyaya', 271)
# (u'Philosophy Of Perception', 270)
# (u'Taoism', 270)
# (u'Positivism', 270)
# (u'Jain Philosophy', 269)
# (u'Samkhya', 269)
# (u'Vaisheshika', 269)
# (u'Individualism', 268)
# (u'Foundationalism', 268)
# (u'Philosophy Of Space And Time', 268)
# (u'Virtue Ethics', 267)
# (u'Anarchism', 267)
# (u'Humanism', 267)
# (u'Zen', 267)
# (u'Charvaka', 267)
# (u'Philosophy And Economics', 265)
# (u'Communitarianism', 265)
# (u'Advaita Vedanta', 265)
# (u'Epicureanism', 264)
# (u'Scientific Realism', 264)
# (u'Anekantavada', 263)
# (u'Mohism', 263)
# (u'Reality', 263)
# (u'Social Constructionism', 263)
# (u'Fideism', 263)
# (u'Philosophy Of Religion', 262)
# (u'Relativism', 262)
# (u'M\u012bm\u0101\u1e43s\u0101', 262)
# (u'Philosophy Of Information', 262)
# (u'Philosophical Realism', 262)
# (u'Conservatism', 261)
# (u'Social Contract', 261)
# (u'\u0100j\u012bvika', 260)
# (u'Yoga Sutras Of Patanjali', 260)
# (u'Philosophy Of Artificial Intelligence', 260)
# (u'Coherentism', 259)
# (u'Philosophy Of Education', 259)
# (u'Nihilism', 259)
# (u'Phenomenology (Philosophy)', 258)
# (u'Medieval Philosophy', 258)
# (u'Constructivist Epistemology', 258)
# (u'Collectivism', 257)
# (u'Sautr\u0101ntika', 257)
# (u'Vishishtadvaita', 257)
# (u'Scientism', 257)
# (u'Structuralism', 256)
# (u'Platonism', 256)
# (u'Falsifiability', 256)
# (u'Pyrrhonism', 256)

# %%
'''
Partial credit to Networkx module
'''
def pagerank(G, alpha=0.85, personalization=None, max_iter=100, tol=1.0e-6, nstart=None, weight='weight', dangling=None): 


    if len(G) == 0: 
        return {} 
    
    if not G.is_directed():
        D = G.to_directed()
    else:
        D = G

    # Create a copy in (right) stochastic form 
    W = nx.stochastic_graph(D, weight=weight) 
    N = W.number_of_nodes() 

    # Choose fixed starting vector if not given 
    if nstart is None:     
        x = dict.fromkeys(W, 1.0 / N) 
    else: 
        # Normalized nstart vector 
        s = float(sum(nstart.values()))    
        x = dict((k, v / s) for k, v in nstart.items())     

    if personalization is None: 

        # Assign uniform personalization vector if not given 
        p = dict.fromkeys(W, 1.0 / N) 
    else: 
        missing = set(G) - set(personalization) 
        if missing: 
            raise NetworkXError('Personalization dictionary '
                                'must have a value for every node. '
                                'Missing nodes %s' % missing) 
        s = float(sum(personalization.values())) 
        p = dict((k, v / s) for k, v in personalization.items()) 

    if dangling is None: 
        
        # Use personalization vector if dangling vector not specified 
        dangling_weights = p 
    else: 
        
        missing = set(G) - set(dangling) 
        if missing: 
            raise NetworkXError('Dangling node dictionary '
                                'must have a value for every node. '
                                'Missing nodes %s' % missing) 
        s = float(sum(dangling.values())) 
        dangling_weights = dict((k, v/s) for k, v in dangling.items()) 
    dangling_nodes = [n for n in W if W.out_degree(n, weight=weight) == 0.0] 

    # power iteration: make up to max_iter iterations 
    for _ in range(max_iter): 
        
        xlast = x 
        x = dict.fromkeys(xlast.keys(), 0) 
        danglesum = alpha * sum(xlast[n] for n in dangling_nodes) 
        for n in x: 
            # left multiply x^T=xlast^T*W 
            for nbr in W[n]: 
                x[nbr] += alpha * xlast[n] * W[n][nbr][weight] 
            x[n] += danglesum * dangling_weights[n] + (1.0 - alpha) * p[n] 

        # check convergence, l1 norm    
        err = sum([abs(x[n] - xlast[n]) for n in x]) 
        if err < N*tol:      
            return x    
    raise NetworkXError('pagerank: power iteration failed to converge '
                        'in %d iterations.' % max_iter)

# %%
#clear up the network graph
pr=nx.pagerank(G,0.85)
for (i,j) in G.nodes(data=True):
    j.clear()
    i = i.encode('utf8', 'replace')

# %%
nx.set_node_attributes(G, pr, 'pr')

# %%
nx.write_gml(G, 'philosophy_clean_2.gml')
